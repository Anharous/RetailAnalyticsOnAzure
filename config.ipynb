# %%
storage_account_name = "my_acnt_name"
storage_account_key = "my_acnt_key"
container_name = "my_ADLSstorage_container_name"

base_path = f"abfss://{container_name}@{storage_account_name}.dfs.core.windows.net/"
storage_options = {f"fs.azure.account.key.{storage_account_name}.dfs.core.windows.net":storage_account_key}

# %%
config_path = f"{base_path}configs/metaData_config.json"
config_df = spark.read.option("multiline", "true").options(**storage_options).json(config_path)
METADATA_CONFIG = config_df.first().asDict(recursive=True)
